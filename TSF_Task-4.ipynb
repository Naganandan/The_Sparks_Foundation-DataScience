# %% [markdown]
# ## Data Science And Business Analytics Internship At The Sparks Foundation.
#
# #GRIPJUNE21
#
# Author : Naganandan P
#
# Task-3
# Exploratory Data Analysis
#
# Link to Dataset: https://bit.ly/2TK5Xn5

# %%
#Importing all libraries required
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline
from sklearn import datasets
import seaborn as sns

# %%
df=pd.read_csv('globalterrorismdb_0718dist.csv',low_memory=False)         #Reading the dataset using pandas

# %%
df.shape         #Gives the number of rows and columns
# Out:
# (181691, 135)

# %%
df.ndim
# Out:
# 2

# %%
df.head(2)           #Display first two rows of the dataset
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
#
# [2 rows x 135 columns]

# %%
df.describe(include='all')         #Description of the dataset
# Out:
#              eventid          iyear         imonth           iday  \
# count   1.816910e+05  181691.000000  181691.000000  181691.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    2.002705e+11    2002.638997       6.467277      15.505644
# std     1.325957e+09      13.259430       3.388303       8.814045
# min     1.970000e+11    1970.000000       0.000000       0.000000
# 25%     1.991021e+11    1991.000000       4.000000       8.000000
# 50%     2.009022e+11    2009.000000       6.000000      15.000000
# 75%     2.014081e+11    2014.000000       9.000000      23.000000
# max     2.017123e+11    2017.000000      12.000000      31.000000
#
#                    approxdate       extended resolution        country  \
# count                    9239  181691.000000       2220  181691.000000
# ...

# %%
df.info()           #information about all the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.dtypes          #Display the data types of the attribute in the data set
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.count()
# Out:
# eventid            181691
# iyear              181691
# imonth             181691
# iday               181691
# extended           181691
# country            181691
# country_txt        181691
# region             181691
# region_txt         181691
# vicinity           181691
# crit1              181691
# crit2              181691
# crit3              181691
# success            181691
# suicide            181691
# attacktype1        181691
# attacktype1_txt    181691
# targtype1          181691
# targtype1_txt      181691
# gname              181691
# individual         181691
# weaptype1          181691
# weaptype1_txt      181691
# property           181691
# dbsource           181691
# INT_LOG            181691
# INT_IDEO           181691
# INT_MISC           181691
# INT_ANY            181691
# dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.dropna(axis=1,inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#               eventid     iyear    imonth      iday  extended   country  \
# eventid      1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear        0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth       0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday         0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended     0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# country     -0.135039 -0.135023 -0.006305  0.003468 -0.020466  1.000000
# region       0.401371  0.401384 -0.002999  0.009710  0.038389  0.148597
# vicinity     0.070646  0.070659 -0.004501 -0.005367  0.017784 -0.012291
# crit1        0.002019  0.001995  0.001568  0.011434 -0.015029 -0.006646
# crit2        0.026215  0.026211  0.001734 -0.002702  0.001249 -0.038480
# crit3       -0.016789 -0.016784  0.000176 -0.004889  0.048533 -0.040288
# success     -0.082972 -0.082963 -0.002845 -0.011802  0.073233 -0.037827
# ...

# %% [markdown]
# # Data Visualization

# %%
plt.rcParams['figure.figsize']=15,11
sns.countplot(x=df['iyear'])
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack year')
plt.title('Increase in terror',size=25,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Increase in terror')

# %%
plt.rcParams['figure.figsize']=15,11
sns.countplot(x=df['iyear'],hue='success',data=df)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack year')
# Out:
# Text(0.5, 0, 'Attack year')

# %%
plt.rcParams['figure.figsize']=15,11
sns.countplot(x=df['region_txt'],hue='success',data=df)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack Region')
# Out:
# Text(0.5, 0, 'Attack Region')

# %%
plt.rcParams['figure.figsize']=15,11
sns.barplot(x=df['country_txt'].value_counts()[:20].index,y=df['country_txt'].value_counts()[:20].values)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack year')
plt.title('Country wise attack',size=25,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Country wise attack')

# %%
plt.rcParams['figure.figsize']=15,11
sns.barplot(x=df['attacktype1_txt'].value_counts()[:20].index,y=df['attacktype1_txt'].value_counts()[:20].values)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack year')
plt.title('Attack year',size=25,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Attack year')

# %% [markdown]
# ## Conclusion
#
#   Iraq ranked first on the gloabal terrorism for their terrorist activity followed by Pakistan, Afghanisthan and so on
#   Most targeted areas are private citizens and property,military and police so on.
